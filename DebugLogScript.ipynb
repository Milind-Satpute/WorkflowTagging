# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Nov  5 15:56:13 2023

@author: satpum
"""

import json;
import pandas as pd
import time 
import os, shutil
from bs4 import BeautifulSoup 
import requests 
import re


print('===============IMPORTING DATA====================')
directoryName='./Data/Input/ge2/Es_SideCar_Logs_ge2.json'
if not os.path.exists(directoryName):
   os.makedirs(directoryName)


print('=======Getting Data From '+directoryName+'============')

f1  = open(directoryName, encoding="utf8")


dataSideCarLogs = json.load(f1)
#os.close(f1)

sourceArray=[]
sidecarDataFrame= pd.DataFrame(dataSideCarLogs,columns = ['_source'])
sourceArrayDataFrame= pd.DataFrame(sidecarDataFrame['_source'])
#sourceArrayDataFrame['_source'].to_json('./Data/Input/ge2/Data2.json',orient='records')
#print(sourceArrayDataFrame)

log_processed=[]
for row in sourceArrayDataFrame['_source']:
    log_processed.append(row)
#print(log_processed)    



logprocessedDF= pd.DataFrame(log_processed,columns=['log_processed'])

#print(logprocessedDF)


logArray=[]
for log in logprocessedDF['log_processed']:
    logArray.append(log)

logsDF=pd.DataFrame(logArray,columns=['dpid','message','domain'])


print('===============READING HITS ====================')


#logsDF=pd.DataFrame(logs,columns=['dpid','message','domain']) 
#print(logsDF.head(2))
uniquiDpid=[]
uniquiDpid=logsDF['dpid'].unique();

print('============Saving logs in Dpid Name file ===============')
message=[]

#print(logsDF[(logsDF['dpid']=='7020000346408')]['message'])

for dpid in uniquiDpid:
    fileName=dpid+'.json'
    if not os.path.exists('./Data/Output/Final/Dpids'):
       os.makedirs('./Data/Output/Final/Dpids')
    pathName='./Data/Output/Final/Dpids/'+fileName
    series=logsDF[(logsDF['dpid']==dpid)]['message']
    #print(type(series))
    pdf=series.to_frame()
#    pdf=pdf.rename(columns = {0:'message'})
    pdf['message'].to_json(pathName,orient='records')
    #logsDF[(logsDF['dpid']==dpid)]['message'].to_json(pathName)
    #print('===saving file at '+pathName) 



print('============Creating Data Set ===============')

uniquiDpid=[]
uniquiDpid=logsDF['dpid'].unique();

message=''
messageArray=[]
for dpid in uniquiDpid:
    fileName=dpid+'.json'
    directoryName='./Data/Output/Final/Dpids/'+fileName
    print('=======Getting Data From '+directoryName+'============')
    f1  = open(directoryName, encoding="utf8")
    logs = json.load(f1)
    logsDF=pd.DataFrame(logs,columns=['logs'])
    #print(logsDF)

    logarray=[]
    for index, row in logsDF.iterrows():
        message=message +row;
    messageArray.append(message)
    print(len(messageArray))


print('============Done creating MessageArray ===============')

LogsDataSetDF=pd.DataFrame(messageArray)

newLogArray=[]

LogsDataSetDF['logs'] = LogsDataSetDF['logs'].replace(to_replace=r'^https?:\/\/.*[\r\n]*',value='',regex=True)

#print(LogsDataSetDF.head())
#for index, row in LogsDataSetDF.iterrows():
#    row = re.sub(r'^https?:\/\/.*[\r\n]*', '', row, flags=re.MULTILINE)
#    newLogArray.append(row)
    

#text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    

print('============Saving DataSet ===============')
    
pathName='./Data/Output/final/DataSet/'    

if not os.path.exists(pathName): 
    os.makedirs(pathName)  

fileName='Final_Log_DataSet'+ time.strftime("%Y%m%d-%H%M%S")+'.json'
LogsDataSetDF.to_json(pathName+fileName,orient='records')
print(os.path.abspath(pathName+fileName))

print('============Saving DataSet at '+fileName+'====================')
print('============Finish Saving DataSet ===============')
# Out:
# ===============IMPORTING DATA====================
# =======Getting Data From ./Data/Input/ge2/Es_SideCar_Logs_ge2.json============
# ===============READING HITS ====================
# ============Saving logs in Dpid Name file ===============
# ============Creating Data Set ===============
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270320.json============
# 1
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270321.json============
# 2
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270322.json============
# 3
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270323.json============
# 4
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270324.json============
# 5
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270325.json============
# 6
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270326.json============
# 7
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270327.json============
# 8
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270328.json============
# 9
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270330.json============
# 10
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270331.json============
# 11
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270332.json============
# 12
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270333.json============
# 13
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270334.json============
# 14
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270335.json============
# 15
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270336.json============
# 16
# =======Getting Data From ./Data/Output/Final/Dpids/2003238216388.json============
# 17
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270337.json============
# 18
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270339.json============
# 19
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270340.json============
# 20
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270341.json============
# 21
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270343.json============
# 22
# =======Getting Data From ./Data/Output/Final/Dpids/2003238216487.json============
# 23
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270344.json============
# 24
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270345.json============
# 25
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270346.json============
# 26
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270347.json============
# 27
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270348.json============
# 28
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270349.json============
# 29
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270350.json============
# 30
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270351.json============
# 31
# =======Getting Data From ./Data/Output/Final/Dpids/2003238217527.json============
# 32
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270353.json============
# 33
# =======Getting Data From ./Data/Output/Final/Dpids/2003238217782.json============
# 34
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270354.json============
# 35
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270355.json============
# 36
# =======Getting Data From ./Data/Output/Final/Dpids/2003238218087.json============
# 37
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270356.json============
# 38
# =======Getting Data From ./Data/Output/Final/Dpids/2003238219788.json============
# 39
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270357.json============
# 40
# =======Getting Data From ./Data/Output/Final/Dpids/2003238219820.json============
# 41
# =======Getting Data From ./Data/Output/Final/Dpids/2003238219804.json============
# 42
# =======Getting Data From ./Data/Output/Final/Dpids/2003238219861.json============
# 43
# =======Getting Data From ./Data/Output/Final/Dpids/2003238219846.json============
# 44
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270358.json============
# 45
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270359.json============
# 46
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270360.json============
# 47
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270361.json============
# 48
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270362.json============
# 49
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270363.json============
# 50
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270364.json============
# 51
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270365.json============
# 52
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270366.json============
# 53
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270367.json============
# 54
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270368.json============
# 55
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270369.json============
# 56
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270370.json============
# 57
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270371.json============
# 58
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270372.json============
# 59
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270376.json============
# 60
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270379.json============
# 61
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270382.json============
# 62
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270388.json============
# 63
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270389.json============
# 64
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270390.json============
# 65
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270391.json============
# 66
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270392.json============
# 67
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270393.json============
# 68
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270394.json============
# 69
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270395.json============
# 70
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270396.json============
# 71
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270397.json============
# 72
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270398.json============
# 73
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270399.json============
# 74
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270401.json============
# 75
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270402.json============
# 76
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270403.json============
# 77
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270404.json============
# 78
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270405.json============
# 79
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270406.json============
# 80
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270408.json============
# 81
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270409.json============
# 82
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270410.json============
# 83
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270411.json============
# 84
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270412.json============
# 85
# =======Getting Data From ./Data/Output/Final/Dpids/2003238218202.json============
# 86
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270413.json============
# 87
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270414.json============
# 88
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270415.json============
# 89
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270417.json============
# 90
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270418.json============
# 91
# =======Getting Data From ./Data/Output/Final/Dpids/2003238218327.json============
# 92
# =======Getting Data From ./Data/Output/Final/Dpids/2003238221107.json============
# 93
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270419.json============
# 94
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270420.json============
# 95
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270421.json============
# 96
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270423.json============
# 97
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270422.json============
# 98
# =======Getting Data From ./Data/Output/Final/Dpids/2003238221321.json============
# 99
# =======Getting Data From ./Data/Output/Final/Dpids/2003238220901.json============
# 100
# =======Getting Data From ./Data/Output/Final/Dpids/2003238220885.json============
# 101
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270424.json============
# 102
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270425.json============
# 103
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270426.json============
# 104
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270428.json============
# 105
# =======Getting Data From ./Data/Output/Final/Dpids/2003238222006.json============
# 106
# =======Getting Data From ./Data/Output/Final/Dpids/2003238221982.json============
# 107
# =======Getting Data From ./Data/Output/Final/Dpids/2003238222022.json============
# 108
# =======Getting Data From ./Data/Output/Final/Dpids/2003238221966.json============
# 109
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270430.json============
# 110
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270431.json============
# 111
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270432.json============
# 112
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270433.json============
# 113
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270434.json============
# 114
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270435.json============
# 115
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270436.json============
# 116
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270437.json============
# 117
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270438.json============
# 118
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270439.json============
# 119
# =======Getting Data From ./Data/Output/Final/Dpids/7020000270440.json============
# 120
# ============Done creating MessageArray ===============
# ============Saving DataSet ===============
# C:\Users\Satpum\DebugLogTagging\Data\Output\final\DataSet\Final_Log_DataSet20231121-173213.json
# ============Saving DataSet at Final_Log_DataSet20231121-173213.json====================
# ============Finish Saving DataSet ===============

# %%
print('============Deleting Dpid Files  ===============')

folder = './Data/Output/Final/Dpids/'
for filename in os.listdir(folder):
    file_path = os.path.join(folder, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (file_path, e))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for message in LogsDataSetDF['logs']:
#       2     print(message)
#
# NameError: name 'LogsDataSetDF' is not defined
